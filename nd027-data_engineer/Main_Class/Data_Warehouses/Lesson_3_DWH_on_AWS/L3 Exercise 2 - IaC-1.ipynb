# %% [markdown]
# # Exercise 2: Creating Redshift Cluster using the AWS python SDK
# ## An example of Infrastructure-as-code

# %%
import pandas as pd
import boto3
import json

# %% [markdown]
# # STEP 0: Make sure you have an AWS secret and access key
#
# - Create a new IAM user in your AWS account
# - Give it `AdministratorAccess`, From `Attach existing policies directly` Tab
# - Take note of the access key and secret
# - Edit the file `dwh.cfg` in the same folder as this notebook and fill
# <font color='red'>
# <BR>
# [AWS]<BR>
# KEY= YOUR_AWS_KEY<BR>
# SECRET= YOUR_AWS_SECRET<BR>
# <font/>

# %% [markdown]
# # Load DWH Params from a file

# %%
import configparser
config = configparser.ConfigParser()
config.read_file(open('dwh.cfg'))

KEY                    = config.get('AWS','KEY')
SECRET                 = config.get('AWS','SECRET')

DWH_CLUSTER_TYPE       = config.get("DWH","DWH_CLUSTER_TYPE")
DWH_NUM_NODES          = config.get("DWH","DWH_NUM_NODES")
DWH_NODE_TYPE          = config.get("DWH","DWH_NODE_TYPE")

DWH_CLUSTER_IDENTIFIER = config.get("DWH","DWH_CLUSTER_IDENTIFIER")
DWH_DB                 = config.get("DWH","DWH_DB")
DWH_DB_USER            = config.get("DWH","DWH_DB_USER")
DWH_DB_PASSWORD        = config.get("DWH","DWH_DB_PASSWORD")
DWH_PORT               = config.get("DWH","DWH_PORT")

DWH_IAM_ROLE_NAME      = config.get("DWH", "DWH_IAM_ROLE_NAME")

(DWH_DB_USER, DWH_DB_PASSWORD, DWH_DB)

pd.DataFrame({"Param":
                  ["DWH_CLUSTER_TYPE", "DWH_NUM_NODES", "DWH_NODE_TYPE", "DWH_CLUSTER_IDENTIFIER", "DWH_DB", "DWH_DB_USER", "DWH_DB_PASSWORD", "DWH_PORT", "DWH_IAM_ROLE_NAME"],
              "Value":
                  [DWH_CLUSTER_TYPE, DWH_NUM_NODES, DWH_NODE_TYPE, DWH_CLUSTER_IDENTIFIER, DWH_DB, DWH_DB_USER, DWH_DB_PASSWORD, DWH_PORT, DWH_IAM_ROLE_NAME]
             })
# Out:
#                     Param       Value
# 0        DWH_CLUSTER_TYPE  multi-node
# 1           DWH_NUM_NODES           4
# 2           DWH_NODE_TYPE   dc2.large
# 3  DWH_CLUSTER_IDENTIFIER  dwhCluster
# 4                  DWH_DB         dwh
# 5             DWH_DB_USER     dwhuser
# 6         DWH_DB_PASSWORD    Passw0rd
# 7                DWH_PORT        5439
# 8       DWH_IAM_ROLE_NAME     dwhRole

# %% [markdown]
# ## Create clients for EC2, S3, IAM, and Redshift

# %%
import boto3

args = {
    "region_name": "us-west-2",
    "aws_access_key_id": KEY,
    "aws_secret_access_key": SECRET
}

ec2 = boto3.resource('ec2', **args)
s3 = boto3.resource('s3', **args)
iam = boto3.client('iam', **args)
redshift = boto3.client('redshift', **args)

# %% [markdown]
# ## Check out the sample data sources on S3

# %%
sampleDbBucket =  s3.Bucket("awssampledbuswest2")

# TODO: Iterate over bucket objects starting with "ssbgz" and print
for obj in sampleDbBucket.objects.filter(Prefix="ssbgz"):
    print(obj)
# Out:
# s3.ObjectSummary(bucket_name='awssampledbuswest2', key='ssbgz/')
# s3.ObjectSummary(bucket_name='awssampledbuswest2', key='ssbgz/customer0002_part_00.gz')
# s3.ObjectSummary(bucket_name='awssampledbuswest2', key='ssbgz/dwdate.tbl.gz')
# s3.ObjectSummary(bucket_name='awssampledbuswest2', key='ssbgz/lineorder0000_part_00.gz')
# s3.ObjectSummary(bucket_name='awssampledbuswest2', key='ssbgz/lineorder0001_part_00.gz')
# s3.ObjectSummary(bucket_name='awssampledbuswest2', key='ssbgz/lineorder0002_part_00.gz')
# s3.ObjectSummary(bucket_name='awssampledbuswest2', key='ssbgz/lineorder0003_part_00.gz')
# s3.ObjectSummary(bucket_name='awssampledbuswest2', key='ssbgz/lineorder0004_part_00.gz')
# s3.ObjectSummary(bucket_name='awssampledbuswest2', key='ssbgz/lineorder0005_part_00.gz')
# s3.ObjectSummary(bucket_name='awssampledbuswest2', key='ssbgz/lineorder0006_part_00.gz')
# s3.ObjectSummary(bucket_name='awssampledbuswest2', key='ssbgz/lineorder0007_part_00.gz')
# s3.ObjectSummary(bucket_name='awssampledbuswest2', key='ssbgz/part0000_part_00.gz')
# s3.ObjectSummary(bucket_name='awssampledbuswest2', key='ssbgz/part0001_part_00.gz')
# s3.ObjectSummary(bucket_name='awssampledbuswest2', key='ssbgz/part0002_part_00.gz')
# s3.ObjectSummary(bucket_name='awssampledbuswest2', key='ssbgz/part0003_part_00.gz')
# s3.ObjectSummary(bucket_name='awssampledbuswest2', key='ssbgz/supplier.tbl_0000_part_00.gz')
# s3.ObjectSummary(bucket_name='awssampledbuswest2', key='ssbgz/supplier0001_part_00.gz')
# s3.ObjectSummary(bucket_name='awssampledbuswest2', key='ssbgz/supplier0002_part_00.gz')
# s3.ObjectSummary(bucket_name='awssampledbuswest2', key='ssbgz/supplier0003_part_00.gz')

# %% [markdown]
# ## STEP 1: IAM ROLE
# - Create an IAM Role that makes Redshift able to access S3 bucket (ReadOnly)

# %%
# TODO: Create the IAM role
try:
    print('1.1 Creating a new IAM Role')
    dwhRole = iam.create_role(
        Path='/',
        RoleName=DWH_IAM_ROLE_NAME,
        Description = "Allows Redshift clusters to call AWS services on your behalf.",
        AssumeRolePolicyDocument=json.dumps(
            {'Statement': [{'Action': 'sts:AssumeRole',
               'Effect': 'Allow',
               'Principal': {'Service': 'redshift.amazonaws.com'}}],
             'Version': '2012-10-17'})
    )    

except Exception as e:
    print(e)
# Out:
# 1.1 Creating a new IAM Role

# %%
# TODO: Attach Policy
print('1.2 Attaching Policy')
iam.attach_role_policy(RoleName=DWH_IAM_ROLE_NAME,
                       PolicyArn="arn:aws:iam::aws:policy/AmazonS3ReadOnlyAccess"
                      )['ResponseMetadata']['HTTPStatusCode']
# Out:
# 1.2 Attaching Policy
# 200

# %%
# TODO: Get and print the IAM role ARN
print('1.3 Get the IAM role ARN')
roleArn = iam.get_role(RoleName=DWH_IAM_ROLE_NAME)['Role']['Arn']
print(roleArn)
# Out:
# 1.3 Get the IAM role ARN
# arn:aws:iam::769590699532:role/dwhRole

# %% [markdown]
# ## STEP 2:  Redshift Cluster
#
# - Create a RedShift Cluster
# - For complete arguments to `create_cluster`, see [docs](https://boto3.amazonaws.com/v1/documentation/api/latest/reference/services/redshift.html#Redshift.Client.create_cluster)

# %%
try:
    response = redshift.create_cluster(        
        # parameters for hardware
        ClusterType=DWH_CLUSTER_TYPE,
        NodeType=DWH_NODE_TYPE,
        NumberOfNodes=int(DWH_NUM_NODES),

        # parameters for identifiers & credentials
        DBName=DWH_DB,
        ClusterIdentifier=DWH_CLUSTER_IDENTIFIER,
        MasterUsername=DWH_DB_USER,
        MasterUserPassword=DWH_DB_PASSWORD,
        
        # parameter for role (to allow s3 access)
        IamRoles=[roleArn]
    )
except Exception as e:
    print(e)
# Out:
# An error occurred (ClusterAlreadyExists) when calling the CreateCluster operation: Cluster already exists

# %% [markdown]
# ## 2.1 *Describe* the cluster to see its status
# - run this block several times until the cluster status becomes `Available`

# %%
def prettyRedshiftProps(props):
    pd.set_option('display.max_colwidth', -1)
    keysToShow = ["ClusterIdentifier", "NodeType", "ClusterStatus", "MasterUsername", "DBName", "Endpoint", "NumberOfNodes", 'VpcId']
    x = [(k, v) for k,v in props.items() if k in keysToShow]
    return pd.DataFrame(data=x, columns=["Key", "Value"])

myClusterProps = redshift.describe_clusters(ClusterIdentifier=DWH_CLUSTER_IDENTIFIER)['Clusters'][0]
prettyRedshiftProps(myClusterProps)
# Out:
#                  Key  \
# 0  ClusterIdentifier
# 1  NodeType
# 2  ClusterStatus
# 3  MasterUsername
# 4  DBName
# 5  Endpoint
# 6  VpcId
# 7  NumberOfNodes
#
#                                                                                    Value
# 0  dwhcluster
# 1  dc2.large
# 2  available
# 3  dwhuser
# 4  dwh
# 5  {'Address': 'dwhcluster.cnqie2ev0tzz.us-west-2.redshift.amazonaws.com', 'Port': 5439}
# 6  vpc-d8b1c7a0
# 7  4

# %% [markdown]
# <h2> 2.2 Take note of the cluster <font color='red'> endpoint and role ARN </font> </h2>

# %% [markdown]
# <font color='red'>DO NOT RUN THIS unless the cluster status becomes "Available" </font>

# %%
DWH_ENDPOINT = myClusterProps['Endpoint']['Address']
DWH_ROLE_ARN = myClusterProps['IamRoles'][0]['IamRoleArn']
print("DWH_ENDPOINT :: ", DWH_ENDPOINT)
print("DWH_ROLE_ARN :: ", DWH_ROLE_ARN)
# Out:
# DWH_ENDPOINT ::  dwhcluster.cnqie2ev0tzz.us-west-2.redshift.amazonaws.com
# DWH_ROLE_ARN ::  arn:aws:iam::769590699532:role/dwhRole

# %% [markdown]
# ## STEP 3: Open an incoming  TCP port to access the cluster endpoint

# %%
try:
    vpc = ec2.Vpc(id=myClusterProps['VpcId'])
    defaultSg = list(vpc.security_groups.all())[0]
    print(defaultSg)
    
    defaultSg.authorize_ingress(
        GroupName= 'default',
        CidrIp='0.0.0.0/0',
        IpProtocol='TCP',
        FromPort=int(DWH_PORT),
        ToPort=int(DWH_PORT)
    )
except Exception as e:
    print(e)
# Out:
# ec2.SecurityGroup(id='sg-00d754f37c4f35cfb')
# An error occurred (InvalidPermission.Duplicate) when calling the AuthorizeSecurityGroupIngress operation: the specified rule "peer: 0.0.0.0/0, TCP, from port: 5439, to port: 5439, ALLOW" already exists

# %% [markdown]
# ## STEP 4: Make sure you can connect to the clusterConnect to the cluster

# %%
# %load_ext sql

# %%
conn_string="postgresql://{}:{}@{}:{}/{}".format(DWH_DB_USER, DWH_DB_PASSWORD, DWH_ENDPOINT, DWH_PORT,DWH_DB)
print(conn_string)
# %sql $conn_string
# Out:
# postgresql://dwhuser:Passw0rd@dwhcluster.cnqie2ev0tzz.us-west-2.redshift.amazonaws.com:5439/dwh
# 'Connected: dwhuser@dwh'

# %%
# %sql SELECT DISTINCT tablename FROM pg_table_def;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cnqie2ev0tzz.us-west-2.redshift.amazonaws.com:5439/dwh
# 900 rows affected.
# [('padb_config_harvest',),
#  ('pg_aggregate',),
#  ('pg_am',),
#  ('pg_amop',),
#  ('pg_amproc',),
#  ('pg_attrdef',),
#  ('pg_attribute',),
#  ('pg_attribute_acl',),
#  ('pg_attribute_info',),
#  ('pg_bar_ddllog',),
#  ('pg_bar_repos',),
#  ('pg_bar_state',),
#  ('pg_cast',),
#  ('pg_class',),
#  ('pg_class_extended',),
#  ('pg_class_info',),
#  ('pg_conf',),
#  ('pg_constraint',),
#  ('pg_conversion',),
#  ('pg_database',),
#  ('pg_database_extended',),
#  ('pg_database_info',),
#  ('pg_default_acl',),
#  ('pg_depend',),
#  ('pg_description',),
#  ('pg_external_schema',),
#  ('pg_group',),
#  ('pg_group_extended',),
#  ('pg_highwatermark',),
#  ('pg_index',),
#  ('pg_indexes',),
#  ('pg_inherits',),
#  ('pg_language',),
#  ('pg_largeobject',),
#  ('pg_library',),
#  ('pg_listener',),
#  ('pg_locks',),
#  ('pg_namespace',),
#  ('pg_namespace_extended',),
#  ('pg_opclass',),
#  ('pg_operator',),
#  ('pg_proc',),
#  ('pg_proc_extended',),
#  ('pg_proc_info',),
#  ('pg_resize',),
#  ('pg_rewrite',),
#  ('pg_rules',),
#  ('pg_settings',),
#  ('pg_shadow',),
#  ('pg_shadow_extended',),
#  ('pg_shdepend',),
#  ('pg_stat_activity',),
#  ('pg_stat_all_indexes',),
#  ('pg_stat_all_tables',),
#  ('pg_stat_database',),
#  ('pg_stat_sys_indexes',),
#  ('pg_stat_sys_tables',),
#  ('pg_stat_user_indexes',),
#  ('pg_stat_user_tables',),
#  ('pg_statio_all_indexes',),
#  ('pg_statio_all_sequences',),
#  ('pg_statio_all_tables',),
#  ('pg_statio_sys_indexes',),
#  ('pg_statio_sys_sequences',),
#  ('pg_statio_sys_tables',),
#  ('pg_statio_user_indexes',),
#  ('pg_statio_user_sequences',),
#  ('pg_statio_user_tables',),
#  ('pg_statistic',),
#  ('pg_statistic_indicator',),
#  ('pg_statistic_multicol',),
#  ('pg_stats',),
#  ('pg_table_def',),
#  ('pg_tables',),
#  ('pg_tablespace',),
#  ('pg_test',),
#  ('pg_trigger',),
#  ('pg_type',),
#  ('pg_udf',),
#  ('pg_user',),
#  ('pg_user_info',),
#  ('pg_views',),
#  ('stcs_abort_idle',),
#  ('stcs_aggr',),
#  ('stcs_aggr_distinct',),
#  ('stcs_alert_event_log',),
#  ('stcs_alter_column_events',),
#  ('stcs_alter_dist_sort',),
#  ('stcs_alter_sortkey_events',),
#  ('stcs_analyze',),
#  ('stcs_analyze_compression',),
#  ('stcs_auto_dispatcher_wlm_occupancy',),
#  ('stcs_auto_maintenance',),
#  ('stcs_auto_maintenance_worker',),
#  ('stcs_auto_worker_levels',),
#  ('stcs_autovacuum_detail',),
#  ('stcs_autovacuum_skip_reason',),
#  ('stcs_awsclient_error',),
#  ('stcs_background_monitor',),
#  ('stcs_backtrace',),
#  ('stcs_backup',),
#  ('stcs_backup_compute',),
#  ('stcs_backup_leader',),
#  ('stcs_bcast',),
#  ('stcs_bkg_compile_info',),
#  ('stcs_blf_efficiency',),
#  ('stcs_block_integrity_error',),
#  ('stcs_block_io_metrics',),
#  ('stcs_block_pins',),
#  ('stcs_block_priority_based_rereplication',),
#  ('stcs_blocklist',),
#  ('stcs_bootstrap',),
#  ('stcs_burst_connection',),
#  ('stcs_burst_manager_personalization',),
#  ('stcs_burst_manager_refresh',),
#  ('stcs_burst_prepare',),
#  ('stcs_burst_query_execution',),
#  ('stcs_burst_refresh',),
#  ('stcs_burst_service_client',),
#  ('stcs_cache_policy_stats',),
#  ('stcs_catalog_bloat',),
#  ('stcs_catalog_rebuild_info',),
#  ('stcs_clear_reps',),
#  ('stcs_client_write_timings',),
#  ('stcs_cmd_requires_top_xact',),
#  ('stcs_codegen',),
#  ('stcs_column_errors',),
#  ('stcs_column_stats',),
#  ('stcs_comm_capture',),
#  ('stcs_comm_diag',),
#  ('stcs_comm_diag_errors',),
#  ('stcs_comm_excess',),
#  ('stcs_comm_integrity_error',),
#  ('stcs_comm_pkt_latency',),
#  ('stcs_comm_pkt_oob_count',),
#  ('stcs_comm_pkt_sent_count',),
#  ('stcs_comm_rexmit',),
#  ('stcs_comm_rexmit_histogram',),
#  ('stcs_command_result',),
#  ('stcs_command_start',),
#  ('stcs_commit_checkpoint',),
#  ('stcs_commit_internal_stats',),
#  ('stcs_commit_regions',),
#  ('stcs_commit_stats',),
#  ('stcs_committed_txn',),
#  ('stcs_compile_info',),
#  ('stcs_compile_service',),
#  ('stcs_complyze',),
#  ('stcs_concurrency_scaling_query_mapping',),
#  ('stcs_concurrency_scaling_usage',),
#  ('stcs_concurrency_scaling_usage_error',),
#  ('stcs_config',),
#  ('stcs_config_chooser',),
#  ('stcs_config_history',),
#  ('stcs_connection_log',),
#  ('stcs_consistency',),
#  ('stcs_core_stat',),
#  ('stcs_cost_control_updates',),
#  ('stcs_cqilog',),
#  ('stcs_create_replication',),
#  ('stcs_ddltext',),
#  ('stcs_dead_tuples_stats',),
#  ('stcs_delete',),
#  ('stcs_disk_cache_stats',),
#  ('stcs_disk_cache_write',),
#  ('stcs_disk_extent_splits',),
#  ('stcs_disk_failures',),
#  ('stcs_disk_full_diag',),
#  ('stcs_disk_speeds',),
#  ('stcs_disk_topology',),
#  ('stcs_disks_blocks_stats',),
#  ('stcs_dist',),
#  ('stcs_dropped_replication',),
#  ('stcs_error',),
#  ('stcs_event_trace',),
#  ('stcs_exec_state',),
#  ('stcs_explain',),
#  ('stcs_external_catalog_calls',),
#  ('stcs_fabric_stats',),
#  ('stcs_federated_calls',),
#  ('stcs_federated_query',),
#  ('stcs_federated_trace',),
#  ('stcs_fetchers',),
#  ('stcs_file_scan',),
#  ('stcs_freed_disk_addrs',),
#  ('stcs_hash',),
#  ('stcs_hash_partitions',),
#  ('stcs_hashjoin',),
#  ('stcs_hashjoin_partitions',),
#  ('stcs_hdr_integrity_error',),
#  ('stcs_incremental_resize_state',),
#  ('stcs_inflight',),
#  ('stcs_insert',),
#  ('stcs_internal_query_details',),
#  ('stcs_invalid_replication',),
#  ('stcs_invariant',),
#  ('stcs_io_error',),
#  ('stcs_io_iscsi_monitor',),
#  ('stcs_io_perf',),
#  ('stcs_io_stat',),
#  ('stcs_lbc_events',),
#  ('stcs_leader_control',),
#  ('stcs_leader_snapshot',),
#  ('stcs_limit',),
#  ('stcs_load_commits',),
#  ('stcs_load_error_info',),
#  ('stcs_load_errors',),
#  ('stcs_load_options',),
#  ('stcs_load_trace',),
#  ('stcs_loaderror_detail',),
#  ('stcs_lwlock',),
#  ('stcs_mark_partitions',),
#  ('stcs_mem_alloc_history',),
#  ('stcs_mem_block_details',),
#  ('stcs_mem_freelist',),
#  ('stcs_mem_leaks',),
#  ('stcs_memefficiency',),
#  ('stcs_memhisto',),
#  ('stcs_memory_pressure_actions',),
#  ('stcs_memory_pressure_state',),
#  ('stcs_memory_pressure_suspects',),
#  ('stcs_merge',),
#  ('stcs_mergejoin',),
#  ('stcs_metadata_step',),
#  ('stcs_minmax_errors',),
#  ('stcs_misc_sys_stat',),
#  ('stcs_mmf_details',),
#  ('stcs_monitoring_logs_internal',),
#  ('stcs_multi_statement_violations',),
#  ('stcs_mutex_contention',),
#  ('stcs_mv_refresh',),
#  ('stcs_mv_state',),
#  ('stcs_nestloop',),
#  ('stcs_net_stat',),
#  ('stcs_netmon_ip',),
#  ('stcs_netmon_mac',),
#  ('stcs_network_throttle',),
#  ('stcs_node_failovers',),
#  ('stcs_nullyze',),
#  ('stcs_omnisql_error',),
#  ('stcs_omnisql_rewrite_rules',),
#  ('stcs_omnisql_rewrite_stats',),
#  ('stcs_parse',),
#  ('stcs_perf_histograms',),
#  ('stcs_pinned_blocks',),
#  ('stcs_plan_explain',),
#  ('stcs_plan_explain_props',),
#  ('stcs_plan_explain_tree',),
#  ('stcs_plan_info',),
#  ('stcs_plan_perf',),
#  ('stcs_plan_qid_map',),
#  ('stcs_plan_querytext',),
#  ('stcs_plan_rule_stats',),
#  ('stcs_plan_state',),
#  ('stcs_prefetch_stats',),
#  ('stcs_print',),
#  ('stcs_proc_stat',),
#  ('stcs_process_state',),
#  ('stcs_project',),
#  ('stcs_query',),
#  ('stcs_query_block_stats',),
#  ('stcs_query_concurrency_scaling_decision',),
#  ('stcs_query_execution_time_prediction',),
#  ('stcs_query_internal',),
#  ('stcs_query_mem_leaks',),
#  ('stcs_query_mem_stats',),
#  ('stcs_query_mem_stats_by_type',),
#  ('stcs_query_memory_cheating',),
#  ('stcs_query_metrics',),
#  ('stcs_query_prediction',),
#  ('stcs_query_tx_metrics',),
#  ('stcs_querytext',),
#  ('stcs_querytext_internal',),
#  ('stcs_range_insert',),
#  ('stcs_redshift_proxy_log',),
#  ('stcs_rehydration_metrics',),
#  ('stcs_remote_access_blocklist',),
#  ('stcs_replacements',),
#  ('stcs_rereplication',),
#  ('stcs_res_leaks',),
#  ('stcs_restarted_sessions',),
#  ('stcs_restarted_sessions_internal',),
#  ('stcs_restore',),
#  ('stcs_result_cache_history',),
#  ('stcs_result_cache_stats',),
#  ('stcs_return',),
#  ('stcs_rlf_scan',),
#  ('stcs_rms_calls',),
#  ('stcs_rpc',),
#  ('stcs_rtf_save',),
#  ('stcs_rtf_stats',),
#  ('stcs_s3_write_block_debug',),
#  ('stcs_s3client',),
#  ('stcs_s3client_error',),
#  ('stcs_s3client_trace',),
#  ('stcs_s3commit_stats',),
#  ('stcs_s3list',),
#  ('stcs_s3log',),
#  ('stcs_s3partition_elimination',),
#  ('stcs_s3pushdown',),
#  ('stcs_s3query',),
#  ('stcs_s3query_billing_trace',),
#  ('stcs_s3query_metering',),
#  ('stcs_s3requests',),
#  ('stcs_s3retries',),
#  ('stcs_sample',),
#  ('stcs_save',),
#  ('stcs_scan',),
#  ('stcs_scan_range_stats',),
#  ('stcs_schema_quota_ddl',),
#  ('stcs_schema_quota_violations',),
#  ('stcs_seg_completed_notify',),
#  ('stcs_segment_ends_cleanly',),
#  ('stcs_segment_starts',),
#  ('stcs_sem_pool',),
#  ('stcs_sem_stat',),
#  ('stcs_sem_usage',),
#  ('stcs_serial_safety_net',),
#  ('stcs_server_write_timings',),
#  ('stcs_session_state',),
#  ('stcs_sessions',),
#  ('stcs_shadow_table_commit',),
#  ('stcs_skr_scan_metrics',),
#  ('stcs_small_table_convert_event',),
#  ('stcs_smfaults',),
#  ('stcs_smfaults_cleared',),
#  ('stcs_smfaults_mval',),
#  ('stcs_smfaults_overflow',),
#  ('stcs_smlog',),
#  ('stcs_snapshotbackup',),
#  ('stcs_sort',),
#  ('stcs_sorted_checker',),
#  ('stcs_sorted_checker_leader',),
#  ('stcs_spatial_index',),
#  ('stcs_spatial_simplify',),
#  ('stcs_spectrum_cache_error',),
#  ('stcs_sshclient_error',),
#  ('stcs_ssn_violation',),
#  ('stcs_stack_trace',),
#  ('stcs_step_parse',),
#  ('stcs_steps',),
#  ('stcs_stored_proc_call',),
#  ('stcs_stored_proc_call_map',),
#  ('stcs_stored_proc_messages',),
#  ('stcs_stream_segs',),
#  ('stcs_superblock_integrity_error',),
#  ('stcs_superblock_vacuum',),
#  ('stcs_swap',),
#  ('stcs_table_partition_scan',),
#  ('stcs_table_partitions_hotness_stats',),
#  ('stcs_terminate',),
#  ('stcs_tiered_storage_controller',),
#  ('stcs_tiered_storage_s3_blocks',),
#  ('stcs_tombstone',),
#  ('stcs_tr_conflict',),
#  ('stcs_transaction_read_write_set',),
#  ('stcs_udf',),
#  ('stcs_udf_compile_error',),
#  ('stcs_udf_log',),
#  ('stcs_udf_trace',),
#  ('stcs_undo_transactions',),
#  ('stcs_undone',),
#  ('stcs_unique',),
#  ('stcs_unload_log',),
#  ('stcs_unload_options',),
#  ('stcs_usage_control',),
#  ('stcs_user_query_rewrite',),
#  ('stcs_userlog',),
#  ('stcs_utilitytext',),
#  ('stcs_vacuum',),
#  ('stcs_vacuum_detail',),
#  ('stcs_vacuum_history',),
#  ('stcs_vacuum_scan_query_usage',),
#  ('stcs_version',),
#  ('stcs_volt_tt_sizes',),
#  ('stcs_vpid',),
#  ('stcs_warning',),
#  ('stcs_window',),
#  ('stcs_wlm_auto_concurrency',),
#  ('stcs_wlm_error',),
#  ('stcs_wlm_query',),
#  ('stcs_wlm_query_preemption',),
#  ('stcs_wlm_rule_action',),
#  ('stcs_wlm_service_class_config',),
#  ('stcs_wlm_trace',),
#  ('stcs_wlm_trace_query_state',),
#  ('stcs_xrestore',),
#  ('stl_abort_idle',),
#  ('stl_aggr',),
#  ('stl_aggr_distinct',),
#  ('stl_alert_event_log',),
#  ('stl_alter_column_events',),
#  ('stl_alter_dist_sort',),
#  ('stl_alter_sortkey_events',),
#  ('stl_analyze',),
#  ('stl_analyze_compression',),
#  ('stl_auto_dispatcher_wlm_occupancy',),
#  ('stl_auto_maintenance',),
#  ('stl_auto_maintenance_worker',),
#  ('stl_auto_worker_levels',),
#  ('stl_autovacuum_detail',),
#  ('stl_autovacuum_skip_reason',),
#  ('stl_awsclient_error',),
#  ('stl_background_monitor',),
#  ('stl_backtrace',),
#  ('stl_backup',),
#  ('stl_backup_compute',),
#  ('stl_backup_leader',),
#  ('stl_bcast',),
#  ('stl_bkg_compile_info',),
#  ('stl_blf_efficiency',),
#  ('stl_block_integrity_error',),
#  ('stl_block_io_metrics',),
#  ('stl_block_pins',),
#  ('stl_block_priority_based_rereplication',),
#  ('stl_blocklist',),
#  ('stl_bootstrap',),
#  ('stl_burst_connection',),
#  ('stl_burst_manager_personalization',),
#  ('stl_burst_manager_refresh',),
#  ('stl_burst_prepare',),
#  ('stl_burst_query_execution',),
#  ('stl_burst_refresh',),
#  ('stl_burst_service_client',),
#  ('stl_cache_policy_stats',),
#  ('stl_catalog_bloat',),
#  ('stl_catalog_rebuild_info',),
#  ('stl_clear_reps',),
#  ('stl_client_write_timings',),
#  ('stl_cmd_requires_top_xact',),
#  ('stl_codegen',),
#  ('stl_column_errors',),
#  ('stl_column_stats',),
#  ('stl_comm_capture',),
#  ('stl_comm_diag',),
#  ('stl_comm_diag_errors',),
#  ('stl_comm_excess',),
#  ('stl_comm_integrity_error',),
#  ('stl_comm_pkt_latency',),
#  ('stl_comm_pkt_oob_count',),
#  ('stl_comm_pkt_sent_count',),
#  ('stl_comm_rexmit',),
#  ('stl_comm_rexmit_histogram',),
#  ('stl_command_result',),
#  ('stl_command_start',),
#  ('stl_commit_checkpoint',),
#  ('stl_commit_internal_stats',),
#  ('stl_commit_regions',),
#  ('stl_commit_stats',),
#  ('stl_committed_txn',),
#  ('stl_compile_info',),
#  ('stl_compile_service',),
#  ('stl_complyze',),
#  ('stl_concurrency_scaling_query_mapping',),
#  ('stl_concurrency_scaling_usage',),
#  ('stl_concurrency_scaling_usage_error',),
#  ('stl_config',),
#  ('stl_config_chooser',),
#  ('stl_config_history',),
#  ('stl_connection_log',),
#  ('stl_consistency',),
#  ('stl_core_stat',),
#  ('stl_cost_control_updates',),
#  ('stl_cqilog',),
#  ('stl_create_replication',),
#  ('stl_ddltext',),
#  ('stl_dead_tuples_stats',),
#  ('stl_delete',),
#  ('stl_disk_cache_stats',),
#  ('stl_disk_cache_write',),
#  ('stl_disk_extent_splits',),
#  ('stl_disk_failures',),
#  ('stl_disk_full_diag',),
#  ('stl_disk_speeds',),
#  ('stl_disk_topology',),
#  ('stl_disks_blocks_stats',),
#  ('stl_dist',),
#  ('stl_dropped_replication',),
#  ('stl_error',),
#  ('stl_event_trace',),
#  ('stl_exec_state',),
#  ('stl_explain',),
#  ('stl_external_catalog_calls',),
#  ('stl_fabric_stats',),
#  ('stl_federated_calls',),
#  ('stl_federated_query',),
#  ('stl_federated_trace',),
#  ('stl_fetchers',),
#  ('stl_file_scan',),
#  ('stl_freed_disk_addrs',),
#  ('stl_hash',),
#  ('stl_hash_partitions',),
#  ('stl_hashjoin',),
#  ('stl_hashjoin_partitions',),
#  ('stl_hdr_integrity_error',),
#  ('stl_incremental_resize_state',),
#  ('stl_inflight',),
#  ('stl_insert',),
#  ('stl_internal_query_details',),
#  ('stl_invalid_replication',),
#  ('stl_invariant',),
#  ('stl_io_error',),
#  ('stl_io_iscsi_monitor',),
#  ('stl_io_perf',),
#  ('stl_io_stat',),
#  ('stl_lbc_events',),
#  ('stl_leader_control',),
#  ('stl_leader_snapshot',),
#  ('stl_limit',),
#  ('stl_load_commits',),
#  ('stl_load_error_info',),
#  ('stl_load_errors',),
#  ('stl_load_options',),
#  ('stl_load_trace',),
#  ('stl_loaderror_detail',),
#  ('stl_lwlock',),
#  ('stl_mark_partitions',),
#  ('stl_mem_alloc_history',),
#  ('stl_mem_block_details',),
#  ('stl_mem_freelist',),
#  ('stl_mem_leaks',),
#  ('stl_memefficiency',),
#  ('stl_memhisto',),
#  ('stl_memory_pressure_actions',),
#  ('stl_memory_pressure_state',),
#  ('stl_memory_pressure_suspects',),
#  ('stl_merge',),
#  ('stl_mergejoin',),
#  ('stl_metadata_step',),
#  ('stl_minmax_errors',),
#  ('stl_misc_sys_stat',),
#  ('stl_mmf_details',),
#  ('stl_monitoring_logs_internal',),
#  ('stl_multi_statement_violations',),
#  ('stl_mutex_contention',),
#  ('stl_mv_refresh',),
#  ('stl_mv_state',),
#  ('stl_nestloop',),
#  ('stl_net_stat',),
#  ('stl_netmon_ip',),
#  ('stl_netmon_mac',),
#  ('stl_network_throttle',),
#  ('stl_node_failovers',),
#  ('stl_nullyze',),
#  ('stl_omnisql_error',),
#  ('stl_omnisql_rewrite_rules',),
#  ('stl_omnisql_rewrite_stats',),
#  ('stl_parse',),
#  ('stl_perf_histograms',),
#  ('stl_pinned_blocks',),
#  ('stl_plan_explain',),
#  ('stl_plan_explain_props',),
#  ('stl_plan_explain_tree',),
#  ('stl_plan_info',),
#  ('stl_plan_perf',),
#  ('stl_plan_qid_map',),
#  ('stl_plan_querytext',),
#  ('stl_plan_rule_stats',),
#  ('stl_plan_state',),
#  ('stl_prefetch_stats',),
#  ('stl_print',),
#  ('stl_proc_stat',),
#  ('stl_process_state',),
#  ('stl_project',),
#  ('stl_query',),
#  ('stl_query_block_stats',),
#  ('stl_query_concurrency_scaling_decision',),
#  ('stl_query_execution_time_prediction',),
#  ('stl_query_internal',),
#  ('stl_query_mem_leaks',),
#  ('stl_query_mem_stats',),
#  ('stl_query_mem_stats_by_type',),
#  ('stl_query_memory_cheating',),
#  ('stl_query_metrics',),
#  ('stl_query_prediction',),
#  ('stl_query_tx_metrics',),
#  ('stl_querytext',),
#  ('stl_querytext_internal',),
#  ('stl_range_insert',),
#  ('stl_redshift_proxy_log',),
#  ('stl_rehydration_metrics',),
#  ('stl_remote_access_blocklist',),
#  ('stl_replacements',),
#  ('stl_rereplication',),
#  ('stl_res_leaks',),
#  ('stl_restarted_sessions',),
#  ('stl_restarted_sessions_internal',),
#  ('stl_restore',),
#  ('stl_result_cache_history',),
#  ('stl_result_cache_stats',),
#  ('stl_return',),
#  ('stl_rlf_scan',),
#  ('stl_rms_calls',),
#  ('stl_rpc',),
#  ('stl_rtf_save',),
#  ('stl_rtf_stats',),
#  ('stl_s3_write_block_debug',),
#  ('stl_s3client',),
#  ('stl_s3client_error',),
#  ('stl_s3client_trace',),
#  ('stl_s3commit_stats',),
#  ('stl_s3list',),
#  ('stl_s3log',),
#  ('stl_s3partition_elimination',),
#  ('stl_s3pushdown',),
#  ('stl_s3query',),
#  ('stl_s3query_billing_trace',),
#  ('stl_s3query_metering',),
#  ('stl_s3requests',),
#  ('stl_s3retries',),
#  ('stl_sample',),
#  ('stl_save',),
#  ('stl_scan',),
#  ('stl_scan_range_stats',),
#  ('stl_schema_quota_ddl',),
#  ('stl_schema_quota_violations',),
#  ('stl_seg_completed_notify',),
#  ('stl_segment_ends_cleanly',),
#  ('stl_segment_starts',),
#  ('stl_sem_pool',),
#  ('stl_sem_stat',),
#  ('stl_sem_usage',),
#  ('stl_serial_safety_net',),
#  ('stl_server_write_timings',),
#  ('stl_session_state',),
#  ('stl_sessions',),
#  ('stl_shadow_table_commit',),
#  ('stl_skr_scan_metrics',),
#  ('stl_small_table_convert_event',),
#  ('stl_smfaults',),
#  ('stl_smfaults_cleared',),
#  ('stl_smfaults_mval',),
#  ('stl_smfaults_overflow',),
#  ('stl_smlog',),
#  ('stl_snapshotbackup',),
#  ('stl_sort',),
#  ('stl_sorted_checker',),
#  ('stl_sorted_checker_leader',),
#  ('stl_spatial_index',),
#  ('stl_spatial_simplify',),
#  ('stl_spectrum_cache_error',),
#  ('stl_sshclient_error',),
#  ('stl_ssn_violation',),
#  ('stl_stack_trace',),
#  ('stl_step_parse',),
#  ('stl_steps',),
#  ('stl_stored_proc_call',),
#  ('stl_stored_proc_call_map',),
#  ('stl_stored_proc_messages',),
#  ('stl_stream_segs',),
#  ('stl_superblock_integrity_error',),
#  ('stl_superblock_vacuum',),
#  ('stl_swap',),
#  ('stl_table_partition_scan',),
#  ('stl_table_partitions_hotness_stats',),
#  ('stl_terminate',),
#  ('stl_tiered_storage_controller',),
#  ('stl_tiered_storage_s3_blocks',),
#  ('stl_tombstone',),
#  ('stl_tr_conflict',),
#  ('stl_transaction_read_write_set',),
#  ('stl_udf',),
#  ('stl_udf_compile_error',),
#  ('stl_udf_log',),
#  ('stl_udf_trace',),
#  ('stl_undo_transactions',),
#  ('stl_undone',),
#  ('stl_unique',),
#  ('stl_unload_log',),
#  ('stl_unload_options',),
#  ('stl_usage_control',),
#  ('stl_user_query_rewrite',),
#  ('stl_userlog',),
#  ('stl_utilitytext',),
#  ('stl_vacuum',),
#  ('stl_vacuum_detail',),
#  ('stl_vacuum_history',),
#  ('stl_vacuum_scan_query_usage',),
#  ('stl_version',),
#  ('stl_volt_tt_sizes',),
#  ('stl_vpid',),
#  ('stl_warning',),
#  ('stl_window',),
#  ('stl_wlm_auto_concurrency',),
#  ('stl_wlm_error',),
#  ('stl_wlm_query',),
#  ('stl_wlm_query_preemption',),
#  ('stl_wlm_rule_action',),
#  ('stl_wlm_service_class_config',),
#  ('stl_wlm_trace',),
#  ('stl_wlm_trace_query_state',),
#  ('stl_xrestore',),
#  ('stv_active_cursors',),
#  ('stv_aio_reads',),
#  ('stv_aio_writes',),
#  ('stv_allocator',),
#  ('stv_alter_dist_sort',),
#  ('stv_block_limits_metadata',),
#  ('stv_block_lru',),
#  ('stv_block_reps',),
#  ('stv_blocklist',),
#  ('stv_burst_manager_cluster_info',),
#  ('stv_cache_policy_stats',),
#  ('stv_catalog_metrics',),
#  ('stv_channel_reservation',),
#  ('stv_channel_sink',),
#  ('stv_channel_source',),
#  ('stv_channel_usage',),
#  ('stv_code_pool',),
#  ('stv_comm_diag_ping_stats',),
#  ('stv_comm_slice',),
#  ('stv_comm_state_orphans',),
#  ('stv_compression',),
#  ('stv_configuration',),
#  ('stv_core_stat',),
#  ('stv_cost_control',),
#  ('stv_cursor_configuration',),
#  ('stv_disk_addresses',),
#  ('stv_disk_extents',),
#  ('stv_disk_map',),
#  ('stv_exec_state',),
#  ('stv_external_databases',),
#  ('stv_external_partitions',),
#  ('stv_fdisk_stats',),
#  ('stv_fragmentation',),
#  ('stv_gui_status',),
#  ('stv_identity_highwater',),
#  ('stv_inflight',),
#  ('stv_interleaved_counts',),
#  ('stv_invalid_replication',),
#  ('stv_invisible_xact',),
#  ('stv_io_local_pending',),
#  ('stv_io_local_pending_time',),
#  ('stv_io_local_times',),
#  ('stv_io_raidp_client_pending',),
#  ('stv_io_raidp_server_pending',),
#  ('stv_io_readahead',),
#  ('stv_io_stat',),
#  ('stv_ip',),
#  ('stv_load_state',),
#  ('stv_local_block_cache_state',),
#  ('stv_locks',),
#  ('stv_mem_alloc_history',),
#  ('stv_mem_fragmentation',),
#  ('stv_mem_freelist',),
#  ('stv_mem_freelist_len',),
#  ('stv_mem_leaks',),
#  ('stv_mv_info',),
#  ('stv_net_stat',),
#  ('stv_networks',),
#  ('stv_nodes',),
#  ('stv_partitions',),
#  ('stv_pg_wal_length',),
#  ('stv_proc_stat',),
#  ('stv_process_state',),
#  ('stv_profiler',),
#  ('stv_query_mem_leaks',),
#  ('stv_query_mem_stats',),
#  ('stv_query_mem_stats_by_type',),
#  ('stv_query_metrics',),
#  ('stv_query_stats',),
#  ('stv_recent_io',),
#  ('stv_recents',),
#  ('stv_resize_library_import',),
#  ('stv_resize_state',),
#  ('stv_resize_table_import',),
#  ('stv_restore_table_state',),
#  ('stv_result_cache',),
#  ('stv_s3_commit_mid',),
#  ('stv_schema_quota_state',),
#  ('stv_sem_usage',),
#  ('stv_session_state',),
#  ('stv_sessions',),
#  ('stv_shmmem_stats',),
#  ('stv_slices',),
#  ('stv_spectrum_cache_state',),
#  ('stv_startup_recovery_state',),
#  ('stv_superblock',),
#  ('stv_superblock_locations',),
#  ('stv_table_interval_map',),
#  ('stv_table_partition_summary',),
#  ('stv_table_partitions',),
#  ('stv_table_vacuum_advisor_info',),
#  ('stv_tbl_column_state',),
#  ('stv_tbl_fragmentation',),
#  ('stv_tbl_perm',),
#  ('stv_tbl_perm_property',),
#  ('stv_tbl_trans',),
#  ('stv_transactions',),
#  ('stv_underrepped_blocks',),
#  ('stv_vacuum_state',),
#  ('stv_vpid',),
#  ('stv_wlm_classification_config',),
#  ('stv_wlm_config',),
#  ('stv_wlm_config_internal',),
#  ('stv_wlm_qmr_config',),
#  ('stv_wlm_query_queue_state',),
#  ('stv_wlm_query_state',),
#  ('stv_wlm_query_task_state',),
#  ('stv_wlm_service_class_config',),
#  ('stv_wlm_service_class_state',),
#  ('stv_xact',),
#  ('svcs_aggr',),
#  ('svcs_alert_event_log',),
#  ('svcs_bcast',),
#  ('svcs_compile',),
#  ('svcs_concurrency_scaling_usage',),
#  ('svcs_delete',),
#  ('svcs_dist',),
#  ('svcs_error',),
#  ('svcs_explain',),
#  ('svcs_hash',),
#  ('svcs_hashjoin',),
#  ('svcs_insert',),
#  ('svcs_limit',),
#  ('svcs_merge',),
#  ('svcs_mergejoin',),
#  ('svcs_nestloop',),
#  ('svcs_parse',),
#  ('svcs_perf_histograms',),
#  ('svcs_plan_info',),
#  ('svcs_project',),
#  ('svcs_query_metrics',),
#  ('svcs_query_report',),
#  ('svcs_query_summary',),
#  ('svcs_return',),
#  ('svcs_s3catalog',),
#  ('svcs_s3client',),
#  ('svcs_s3client_error',),
#  ('svcs_s3list',),
#  ('svcs_s3log',),
#  ('svcs_s3partition_elimination',),
#  ('svcs_s3partition_summary',),
#  ('svcs_s3query',),
#  ('svcs_s3query_metering',),
#  ('svcs_s3query_summary',),
#  ('svcs_s3requests',),
#  ('svcs_s3retries',),
#  ('svcs_save',),
#  ('svcs_scan',),
#  ('svcs_segment_ends_cleanly',),
#  ('svcs_segment_starts',),
#  ('svcs_sort',),
#  ('svcs_stream_segs',),
#  ('svcs_unique',),
#  ('svcs_unload_log',),
#  ('svcs_window',),
#  ('svl_awsclient_error',),
#  ('svl_burst_service_client',),
#  ('svl_compile',),
#  ('svl_federated_query',),
#  ('svl_multi_statement_violations',),
#  ('svl_mv_refresh_status',),
#  ('svl_omnisql_error',),
#  ('svl_qlog',),
#  ('svl_query_concurrency_scaling_status',),
#  ('svl_query_metrics',),
#  ('svl_query_metrics_summary',),
#  ('svl_query_queue_info',),
#  ('svl_query_report',),
#  ('svl_query_summary',),
#  ('svl_s3catalog',),
#  ('svl_s3list',),
#  ('svl_s3log',),
#  ('svl_s3partition',),
#  ('svl_s3partition_summary',),
#  ('svl_s3query',),
#  ('svl_s3query_summary',),
#  ('svl_s3requests',),
#  ('svl_s3retries',),
#  ('svl_spatial_simplify',),
#  ('svl_statementtext',),
#  ('svl_stored_proc_call',),
#  ('svl_stored_proc_messages',),
#  ('svl_terminate',),
#  ('svl_udf_log',),
#  ('svl_user_info',),
#  ('svl_vacuum_percentage',),
#  ('svv_columns',),
#  ('svv_diskusage',),
#  ('svv_external_columns',),
#  ('svv_external_databases',),
#  ('svv_external_partitions',),
#  ('svv_external_schemas',),
#  ('svv_external_tables',),
#  ('svv_interleaved_columns',),
#  ('svv_query_inflight',),
#  ('svv_query_state',),
#  ('svv_restore_table_state',),
#  ('svv_schema_quota_state',),
#  ('svv_sem_usage',),
#  ('svv_sem_usage_leader',),
#  ('svv_table_info',),
#  ('svv_tables',),
#  ('svv_transactions',),
#  ('svv_vacuum_progress',),
#  ('svv_vacuum_summary',),
#  ('systable_globaldict',),
#  ('systable_schema',),
#  ('systable_topology',)]

# %% [markdown]
# ## STEP 5: Clean up your resources

# %% [markdown]
# <b><font color='red'>DO NOT RUN THIS UNLESS YOU ARE SURE <br/>
#     We will be using these resources in the next exercises</span></b>

# %%
#### CAREFUL!!
#-- Uncomment & run to delete the created resources
redshift.delete_cluster( ClusterIdentifier=DWH_CLUSTER_IDENTIFIER,  SkipFinalClusterSnapshot=True)
#### CAREFUL!!
# Out:
# {'Cluster': {'ClusterIdentifier': 'dwhcluster',
#   'NodeType': 'dc2.large',
#   'ClusterStatus': 'deleting',
#   'MasterUsername': 'dwhuser',
#   'DBName': 'dwh',
#   'Endpoint': {'Address': 'dwhcluster.cnqie2ev0tzz.us-west-2.redshift.amazonaws.com',
#    'Port': 5439},
#   'ClusterCreateTime': datetime.datetime(2020, 6, 5, 18, 11, 15, 201000, tzinfo=tzlocal()),
#   'AutomatedSnapshotRetentionPeriod': 1,
#   'ClusterSecurityGroups': [],
#   'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-24e8b077',
#     'Status': 'active'}],
#   'ClusterParameterGroups': [{'ParameterGroupName': 'default.redshift-1.0',
#     'ParameterApplyStatus': 'in-sync'}],
#   'ClusterSubnetGroupName': 'default',
#   'VpcId': 'vpc-d8b1c7a0',
#   'AvailabilityZone': 'us-west-2a',
#   'PreferredMaintenanceWindow': 'wed:06:30-wed:07:00',
#   'PendingModifiedValues': {},
#   'ClusterVersion': '1.0',
#   'AllowVersionUpgrade': True,
#   'NumberOfNodes': 4,
#   'PubliclyAccessible': True,
#   'Encrypted': False,
#   'Tags': [],
#   'EnhancedVpcRouting': False,
#   'IamRoles': [{'IamRoleArn': 'arn:aws:iam::769590699532:role/dwhRole',
#     'ApplyStatus': 'in-sync'}],
#   'MaintenanceTrackName': 'current'},
#  'ResponseMetadata': {'RequestId': '15e196d3-cd5c-4113-8d14-8093833c8f49',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '15e196d3-cd5c-4113-8d14-8093833c8f49',
#    'content-type': 'text/xml',
#    'content-length': '2382',
#    'vary': 'accept-encoding',
#    'date': 'Fri, 05 Jun 2020 18:42:13 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# - run this block several times until the cluster really deleted

# %%
myClusterProps = redshift.describe_clusters(ClusterIdentifier=DWH_CLUSTER_IDENTIFIER)['Clusters'][0]
prettyRedshiftProps(myClusterProps)
# Out:
#                  Key  \
# 0  ClusterIdentifier
# 1  NodeType
# 2  ClusterStatus
# 3  MasterUsername
# 4  DBName
# 5  Endpoint
# 6  VpcId
# 7  NumberOfNodes
#
#                                                                                    Value
# 0  dwhcluster
# 1  dc2.large
# 2  deleting
# 3  dwhuser
# 4  dwh
# 5  {'Address': 'dwhcluster.cnqie2ev0tzz.us-west-2.redshift.amazonaws.com', 'Port': 5439}
# 6  vpc-d8b1c7a0
# 7  4

# %%
#### CAREFUL!!
#-- Uncomment & run to delete the created resources
iam.detach_role_policy(RoleName=DWH_IAM_ROLE_NAME, PolicyArn="arn:aws:iam::aws:policy/AmazonS3ReadOnlyAccess")
iam.delete_role(RoleName=DWH_IAM_ROLE_NAME)
#### CAREFUL!!
# Out:
# {'ResponseMetadata': {'RequestId': '015d9592-b35d-469c-b584-278a2f0ec280',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '015d9592-b35d-469c-b584-278a2f0ec280',
#    'content-type': 'text/xml',
#    'content-length': '200',
#    'date': 'Fri, 05 Jun 2020 18:43:00 GMT'},
#   'RetryAttempts': 0}}
